# %% [markdown]
# # Graphical EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
col_names = ['sepal_length', 
             'sepal_width', 
             'petal_length', 
             'petal_width', 
             'species']

# %%
iris = pd.read_csv('./data/iris.csv', header=None, names=col_names)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ####  Line Plot

# %%
iris.plot(x='sepal_length', y='sepal_width')

plt.show()

# %% [markdown]
# result not useful

# %%
iris.plot(kind='scatter', x='sepal_length', y='sepal_width')

plt.xlabel('sepal length(cm)')
          
plt.ylabel('sepal width (cm)')
          
plt.show()

# %% [markdown]
# #### Boxplot
#
# - Range, min, max
# - Medium
# - Inner Quartiles

# %%
iris.plot(y='sepal_length', kind='box')

plt.ylabel('sepal width (cm)')

plt.show()

# %% [markdown]
# #### Histogram
#
# - Frequency of measurements within bins
# - probability distribution
# - Could be bell shape
#
#
# Customization
# - bins (integer): number of intervals or bins
# - range (tuple): extrema of bins (min, max)
# - normed (boolean): weather to normalize to one
# - cumlative(boolean): compute Cumulative Distribution Function or CDF
# -

# %%
iris.plot(y='sepal_length', kind='hist')

plt.xlabel('sepal length (cm)')

plt.show()

# %%
# keywords improves the histogram

iris.plot(y='sepal_length', kind='hist',
          bins=30, range=(4,8), normed=True)

plt.xlabel('sepal length (cm)')

plt.show()

# %% [markdown]
# Here you see 3 distinct peaks.  This suggests groups or sub populations in the data

# %%
# Cumulative Distribution Function or CDF

iris.plot(y='sepal_length', kind='hist', bins=30,
          range=(4,8), cumulative=True, normed=True)

plt.xlabel('sepal length (cm)')

plt.title('Cumulatie Distribution Function (CDF)')

plt.show()

# %% [markdown]
# CDF used to compute the probability of observing a value in a given range (for instance a sepal width between 2 and 4 cm)
#
# In above, the probability of observing a sepal length up to 5 cm is .2 percent

# %% [markdown]
# ### Word of Warning
#
# Three different Plot Idioms
#
# 1. Iris.plot(kind='hist')
# 2. iris.plt.hist()
# 3. iris.hist()
#
# Syntax and results may differ!
#
# Pandas API still evolving: Check Documentation!

# %% [markdown]
# #### pandas hist, pdf and cdf
#
# Pandas relies on the .hist() method to not only generate histograms, but also plots of probability density functions (PDFs) and cumulative density functions (CDFs).
#
# In this exercise, you will work with a dataset consisting of restaurant bills that includes the amount customers tipped.
#
# The original dataset is provided by the Seaborn package.
#
# Your job is to plot a PDF and CDF for the fraction column of the tips dataset. This column contains information about what fraction of the total bill is comprised of the tip.
#
# Remember, when plotting the PDF, you need to specify normed=True in your call to .hist(), and when plotting the CDF, you need to specify cumulative=True in addition to normed=True.
#
# All necessary modules have been imported and the tips dataset is available in the workspace as df. Also, some formatting code has been written so that the plots you generate will appear on separate rows.

# %%
df = pd.read_csv('./data/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  fraction
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %% [markdown]
# 1. Plot a PDF for the values in fraction with 30 bins between 0 and 30%. The range has been taken care of for you. ax=axes[0] means that this plot will appear in the first row.
# 2. Plot a CDF for the values in fraction with 30 bins between 0 and 30%. Again, the range has been specified for you. To make the CDF appear on the second row, you need to specify ax=axes[1].

# %%
# This formats the plots such that they appear on separate rows
fig, axes = plt.subplots(nrows=2, ncols=1)

# Plot the PDF
# axes[0] plots to top chart
df.fraction.plot(ax=axes[0], kind='hist', bins=30, normed=True, range=(0,.3))
plt.show()

# Plot the CDF
# ax=axes[1] plots to second pot
df.fraction.plot(kind='hist', bins=30,  
                 normed=True, 
                 cumulative=True, 
                 ax=axes[1], 
                 range=(0,.3))

plt.show()

# %% [markdown]
# # Statistical EDA
#
# Graphs are useful, but this provides quantitative results

# %%
# summary statistics
# all Null entries are ignored

iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris[['sepal_length', 'sepal_width']].count()
# Out:
# sepal_length    150
# sepal_width     150
# dtype: int64

# %%
iris['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
# measure central tendancy

iris.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
# measures the spread of the central tendancy

iris.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %% [markdown]
# The median is a very useful statistic, especially in the presence of outliers, when it is more robust than the mean.

# %%
# median splits the data in half, 50% above and below

print(iris.median())

# median is a special example of a quantile
# note the output is the same

q = 0.5

print(iris.quantile(q))
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# Name: 0.5, dtype: float64

# %%
# IQR 
# Inter quartile range
# q can accept a list for the Quantile

q = [0.25, .5, 0.75]

iris.quantile(q)
# Out:
#       sepal_length  sepal_width  petal_length  petal_width
# 0.25           5.1          2.8          1.60          0.3
# 0.50           5.8          3.0          4.35          1.3
# 0.75           6.4          3.3          5.10          1.8

# %%
# Range, or min/max

iris.min()
# Out:
# sepal_length            4.3
# sepal_width               2
# petal_length              1
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %%
iris.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %% [markdown]
# ### Boxplots
#
# You can read the Median, IQR, Range, for all columns of the dataframe.  uses the same data is .describe()

# %%
iris.plot(kind='box')

plt.ylabel('(cm)')

plt.show()

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Autos Dataset

# %%
autos = pd.read_csv('./data/auto-mpg.csv')

# %%
autos.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70     US  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70     US          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70     US         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70     US              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70     US                ford torino

# %%
autos.describe()
# Out:
#               mpg         cyl       displ          hp       weight  \
# count  392.000000  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184
# std      7.805007    1.705783  104.644004   38.491160   849.402560
# min      9.000000    3.000000   68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#             accel          yr
# count  392.000000  392.000000
# mean    15.541327   75.979592
# std      2.758864    3.683737
# min      8.000000   70.000000
# 25%     13.775000   73.000000
# 50%     15.500000   76.000000
# 75%     17.025000   79.000000
# max     24.800000   82.000000

# %%
autos['origin'].unique()
# Out:
# array(['US', 'Asia', 'Europe'], dtype=object)

# %%
asiancars = autos['origin'] == 'Asia'

autos.loc[asiancars, :].count()
# Out:
# mpg       79
# cyl       79
# displ     79
# hp        79
# weight    79
# accel     79
# yr        79
# origin    79
# name      79
# dtype: int64

# %%
us = autos.loc[autos['origin']=='US', :]

# %%
us.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70     US  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70     US          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70     US         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70     US              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70     US                ford torino

# %%
# Out:
# mpg        -3.412449
# cyl         0.805612
# displ      53.100255
# hp         14.579592
# weight    394.905612
# accel      -0.551122
# yr         -0.387755
# dtype: float64
# mpg       -1.364623
# cyl       -0.049788
# displ     -6.267657
# hp         1.406630
# weight   -54.055870
# accel     -0.022844
# yr        -0.023369
# dtype: float64

# %% [markdown]
# Interestingly, it looks like US automobiles weigh more than the global mean.

# %% [markdown]
# #### Bachelor's degrees awarded to women
#
# In this exercise, you will investigate statistics of the percentage of Bachelor's degrees awarded to women from 1970 to 2011. Data is recorded every year for 17 different fields. This data set was obtained from the Digest of Education Statistics.
#
# Your job is to compute the minimum and maximum values of the 'Engineering' column and generate a line plot of the mean value of all 17 academic fields per year. To perform this step, you'll use the .mean() method with the keyword argument axis='columns'. This computes the mean across all columns per row.
#
# The DataFrame has been pre-loaded for you as df with the index set to 'Year'.

# %%
df = pd.read_csv('./data/percent-bachelors-degrees-women-usa.csv')

# %%
df.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
# Print the minimum value of the Engineering column
print(df['Engineering'].min())

# Print the maximum value of the Engineering column
print(df['Engineering'].max())

# Construct the mean percentage per year: mean
mean = df.mean(axis='columns')
# Out:
# 0.8
# 19.0

# %%
# Plot the average percentage per year
mean.plot()

# Display the plot
plt.show()

# %% [markdown]
# #### Quantiles
#
# In this exercise, you'll investigate the probabilities of life expectancy in countries around the world. This dataset contains life expectancy for persons born each year from 1800 to 2015. Since country names change or results are not reported, not every country has values. This dataset was obtained from Gapminder.
#
# First, you will determine the number of countries reported in 2015. There are a total of 260 unique countries in the entire dataset. Then, you will compute the 5th and 95th percentiles of life expectancy over the entire dataset. Finally, you will make a box plot of life expectancy every 50 years from 1800 to 2000. Notice the large change in the distributions over this period.
#
# The dataset has been pre-loaded into a DataFrame called df

# %%
# Print the number of countries reported in 2015
print(df['2015'].count())

# Print the 5th and 95th percentiles
print(df.quantile([0.05, 0.95]))

# Generate a box plot
years = ['1800','1850','1900','1950','2000']
df[years].plot(kind='box')
plt.show()

# %% [markdown]
# # Separating Populations
#
# Up until now, we've used all the rows in the Iris dataframe.  We've ignored the species column entirely.
#
# Knowing there are three different factors, it makes sense to carry out EDA separately on each factor.

# %%
iris['species'].describe()
# Out:
# count                150
# unique                 3
# top       Iris-virginica
# freq                  50
# Name: species, dtype: object

# %%
iris['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Filtering by Species

# %%
indices = iris['species'] == 'Iris-setosa'

setosa = iris.loc[indices, :]

# %%
indices = iris['species'] == 'Iris-versicolor'

versicolor = iris.loc[indices, :]

# %%
indices = iris['species'] == 'Iris-virginica'

virginica = iris.loc[indices, :]

# %%
# because species is no longer needed
# you may delete it from each dataframe

del setosa['species'], versicolor['species'], virginica['species']

# %%
setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# Looking at entire iris dataset.
#
# Notice it's a bit messy with all the histograms overlapping.

# %%
iris.plot(kind='hist', bins=50, range=(0,8),
          alpha=0.3)

plt.title('Entire Iris data set')

plt.xlabel('[cm]')

plt.show()

# %% [markdown]
# We can make plots for each species
#
# Seprated factors show clearer trends for each membership.

# %%
setosa.plot(kind='hist', bins=50, range=(0,8),
          alpha=0.3)

plt.title('Setosa data set')

plt.xlabel('[cm]')

plt.show()

# %%
versicolor.plot(kind='hist', bins=50, range=(0,8),
          alpha=0.3)

plt.title('Versicolor data set')

plt.xlabel('[cm]')

plt.show()

# %%
virginica.plot(kind='hist', bins=50, range=(0,8),
          alpha=0.3)

plt.title('Verginica data set')

plt.xlabel('[cm]')

plt.show()

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
describe_all = iris.describe()

# %%
describe_setosa = setosa.describe()

# %%
describe_versicolor = versicolor.describe()

# %%
describe_virginica = virginica.describe()

# %% [markdown]
# #### Computing errors
#
# We can compute the percentage error for all the statistics.
#
# This is the absolute difference of the correct statistic computed in its own group, from the statistic computed with the whole population divided by the correct statistic.
#
# dataframes can do element wise arthimatic easily

# %%
import numpy as np

# %%
error_setosa = 100 * np.abs(describe_setosa - describe_all)

error_setosa = error_setosa/describe_setosa

# %%
error_setosa
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    200.000000   200.000000    200.000000   200.000000
# mean      16.726595    10.649503    156.739526   391.256831
# std      134.919250    13.796994    916.891608   611.840574
# min        0.000000    13.043478      0.000000     0.000000
# 25%        6.250000    10.400000     14.285714    50.000000
# 50%       16.000000    11.764706    190.000000   550.000000
# 75%       23.076923    10.204082    223.809524   500.000000
# max       36.206897     0.000000    263.157895   316.666667

# %% [markdown]
# Notice that petal_length and petal_width show really large errors.  This is suggested alby the histograms viewed earlier.
#
# These values give a sense of how misleading the statistics were when computed over the whole population rather than by factor

# %% [markdown]
# #### Separate and summarize
#
# Let's use population filtering to determine how the automobiles in the US differ from the global average and standard deviation. How does the distribution of fuel efficiency (MPG) for the US differ from the global average and standard deviation?
#
# In this exercise, you'll compute the means and standard deviations of all columns in the full automobile dataset. Next, you'll compute the same quantities for just the US population and subtract the global values from the US values.
#
# All necessary modules have been imported and the DataFrame has been pre-loaded as df.

# %%
# Compute the global mean and global standard deviation: global_mean, global_std
global_mean = autos.mean()
global_std = autos.std()

# Filter the US population from the origin column: us
us = autos.loc[autos['origin']=='US', :]

# Compute the US mean and US standard deviation: us_mean, us_std
us_mean = us.mean()
us_std = us.std()

# Print the differences
print(us_mean - global_mean)
print(us_std - global_std)

# %% [markdown]
# #### Separate and plot
#
# Population filtering can be used alongside plotting to quickly determine differences in distributions between the sub-populations. You'll work with the Titanic dataset.
#
# There were three passenger classes on the Titanic, and passengers in each class paid a different fare price. In this exercise, you'll investigate the differences in these fare prices.
#
# Your job is to use Boolean filtering and generate box plots of the fare prices for each of the three passenger classes. The fare prices are contained in the 'fare' column and passenger class information is contained in the 'pclass' column.
#
# When you're done, notice the portions of the box plots that differ and those that are similar.
#
# The DataFrame has been pre-loaded for you as titanic.

# %%
titanic = pd.read_csv('./data/titanic.csv')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Display the box plots on 3 separate rows and 1 column
fig, axes = plt.subplots(nrows=3, ncols=1)

# Generate a box plot of the fare prices for the First passenger class
titanic.loc[titanic['pclass'] == 1].plot(ax=axes[0], y='fare', kind='box')

# Generate a box plot of the fare prices for the Second passenger class
titanic.loc[titanic['pclass'] == 2].plot(ax=axes[1], y='fare', kind='box')

# Generate a box plot of the fare prices for the Third passenger class
titanic.loc[titanic['pclass'] == 3].plot(ax=axes[2], y='fare', kind='box')

# Display the plot
plt.show()
